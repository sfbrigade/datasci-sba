# %% [markdown]
# # SQL Querying

# %% [markdown]
# This notebook can be used to query tables in the SBA database. In order to use this notebook, you will need to set an environment variable 'SBA_DWH' to the database connection string. If you do not have the credentials, please slack us at #datasci-sba channel.
#
# **It is best practice to not hard code database URI strings directly in notebooks or code as when we push to Github, that would mean credentials are public for anyone to see.**

# %%
import os

import pandas as pd
pd.options.display.max_columns = 999
import sqlalchemy as sqla
from sqlalchemy import create_engine

SBA_DWH = os.getenv('SBA_DWH')
engine = create_engine(SBA_DWH)

# %% [markdown]
# Below are the tables that currently exist in the database!

# %%
QUERY = """
select *
from information_schema.tables
where table_schema not in ('information_schema', 'pg_catalog', 'public')
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(100)
# Out:
#   table_catalog   table_schema                     table_name  table_type  \
# 0      postgres    data_ingest      sba__foia_7a_2010_present  BASE TABLE
# 1      postgres    data_ingest  census__zip_business_patterns  BASE TABLE
# 2      postgres    data_ingest         sba__foia_7a_1991_1999  BASE TABLE
# 3      postgres    data_ingest         sba__foia_7a_2000_2009  BASE TABLE
# 4      postgres  stg_analytics                       sba_sfdo  BASE TABLE
# 5      postgres    data_ingest     sba__foia_504_1991_present  BASE TABLE
# 6      postgres    data_ingest                  irs__zip_data  BASE TABLE
# 7      postgres  stg_analytics                     irs_income  BASE TABLE
# 8      postgres  stg_analytics                   census_naics  BASE TABLE
# 9      postgres  trg_analytics                  sba_zip_level  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
# 2                         None                 None                      None
# 3                         None                 None                      None
# 4                         None                 None                      None
# 5                         None                 None                      None
# 6                         None                 None                      None
# 7                         None                 None                      None
# 8                         None                 None                      None
# 9                         None                 None                      None
#
#   user_defined_type_schema user_defined_type_name is_insertable_into is_typed  \
# 0                     None                   None                YES       NO
# 1                     None                   None                YES       NO
# 2                     None                   None                YES       NO
# 3                     None                   None                YES       NO
# 4                     None                   None                YES       NO
# 5                     None                   None                YES       NO
# 6                     None                   None                YES       NO
# 7                     None                   None                YES       NO
# 8                     None                   None                YES       NO
# 9                     None                   None                YES       NO
#
#   commit_action
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# 5          None
# 6          None
# 7          None
# 8          None
# 9          None

# %% [markdown]
# ## Edit your own query here!

# %%
QUERY = """
select
  *
from stg_analytics.sba_sfdo
limit 10
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(100)
# Out:
#   program                   borr_name                  borr_street  \
# 0     504           BAY AREA DRILLING  549 GARCIA AVENUE, LOTS 6,7
# 1     504  ARCHITECTURAL ART MFG, INC      7755 PARDEE LANE, STE E
# 2     504    GREEN VALLEY FOODS, INC.           1985 TEXAS STREETG
# 3     504       DIGICOM SYSTEMS, INC.             182 TOPAZ STREET
# 4     504        PATSON'S PRESS, INC.                   508 TASMAN
# 5     504               GEOLEASE, INC         1181 QUARRY LAND 300
# 6     504     MOTOR SOUND CORPORATION          541 DIVISION STREET
# 7     504                PRODUCT PLUS   15900-15906 CONCORD CIRCLE
# 8     504    FAR WEST MARKETING, INC.    1681-1697 INDUSTRIAL ROAD
# 9     504                HOWARD'S INN           2223 FOURTH STREET
#
#      borr_city borr_state  borr_zip  gross_approval approval_date  \
# 0    PITTSBURG         CA     94565          190000    1990-10-11
# 1      OAKLAND         CA     94621          750000    1990-10-31
# 2    FAIRFIELD         CA     94533          297000    1990-12-17
# 3     MILPITAS         CA     95035          750000    1990-12-31
# 4    SUNNYVALE         CA     94089          750000    1991-03-05
# 5   PLEASANTON         CA     94566          274000    1991-03-21
# 6     CAMPBELL         CA     95008          499000    1991-04-26
# 7  MORGAN HILL         CA     95037          545000    1991-06-11
# 8   SAN CARLOS         CA     94070          638000    1991-06-18
# 9       EUREKA         CA     95501          223000    1991-07-05
#
#    approval_fiscal_year first_disbursement_date delivery_method  \
# 0                  1991              1990-12-12             504
# 1                  1991              1991-09-11             504
# 2                  1991                     NaT             504
# 3                  1991              1991-03-13             504
# 4                  1991              1991-07-17             504
# 5                  1991              1991-06-12             504
# 6                  1991              1991-07-17             504
# 7                  1991              1991-08-14             504
# 8                  1991              1991-08-14             504
# 9                  1991              1992-06-17             504
#
#                               subprogram_description initial_interest_rate  \
# 0  Sec. 504 - Loan Guarantees - Private Sector Fi...                  None
# 1  Sec. 504 - Loan Guarantees - Private Sector Fi...                  None
# 2  Sec. 504 - Loan Guarantees - Private Sector Fi...                  None
# 3  Sec. 504 - Loan Guarantees - Private Sector Fi...                  None
# 4  Sec. 504 - Loan Guarantees - Private Sector Fi...                  None
# 5  Sec. 504 - Loan Guarantees - Private Sector Fi...                  None
# 6  Sec. 504 - Loan Guarantees - Private Sector Fi...                  None
# 7  Sec. 504 - Loan Guarantees - Private Sector Fi...                  None
# 8  Sec. 504 - Loan Guarantees - Private Sector Fi...                  None
# 9  Sec. 504 - Loan Guarantees - Private Sector Fi...                  None
#
#    term_in_months  naics_code  \
# 0             240    235930.0
# 1             240    332321.0
# 2             240         NaN
# 3             300    334411.0
# 4             240    323122.0
# 5             240         NaN
# 6             240    421690.0
# 7             240         NaN
# 8             240    323122.0
# 9             240         NaN
#
#                                   naics_description  franchise_code  \
# 0                            Excavation Contractors               1
# 1               Metal Window and Door Manufacturing               1
# 2                                              None           11245
# 3                       Electron Tube Manufacturing               1
# 4                                 Prepress Services               1
# 5                                              None               1
# 6  Other Electronic Parts and Equipment Wholesalers               1
# 7                                              None               1
# 8                                 Prepress Services               1
# 9                                              None               1
#
#   franchise_name project_county project_state             sba_district_office  \
# 0           None   CONTRA COSTA            CA  SAN FRANCISCO DISTRICT OFFICE
# 1           None           LAKE            CA  SAN FRANCISCO DISTRICT OFFICE
# 2  EL POLLO LOCO         SOLANO            CA  SAN FRANCISCO DISTRICT OFFICE
# 3           None    SANTA CLARA            CA  SAN FRANCISCO DISTRICT OFFICE
# 4           None    SANTA CLARA            CA  SAN FRANCISCO DISTRICT OFFICE
# 5           None        ALAMEDA            CA  SAN FRANCISCO DISTRICT OFFICE
# 6           None    SANTA CLARA            CA  SAN FRANCISCO DISTRICT OFFICE
# 7           None    SANTA CLARA            CA  SAN FRANCISCO DISTRICT OFFICE
# 8           None      SAN MATEO            CA  SAN FRANCISCO DISTRICT OFFICE
# 9           None       HUMBOLDT            CA  SAN FRANCISCO DISTRICT OFFICE
#
#    congressional_district business_type loan_status chargeoff_date  \
# 0                    11.0    INDIVIDUAL         PIF           None
# 1                    13.0   CORPORATION         PIF           None
# 2                     3.0   CORPORATION      CANCLD           None
# 3                    17.0   CORPORATION         PIF           None
# 4                    17.0   CORPORATION         PIF           None
# 5                    15.0   CORPORATION         PIF           None
# 6                    18.0   CORPORATION         PIF           None
# 7                    19.0    INDIVIDUAL         PIF           None
# 8                    14.0   CORPORATION         PIF           None
# 9                     2.0   PARTNERSHIP         PIF           None
#
#    gross_chargeoff_amount  jobs_supported  \
# 0                       0              16
# 1                       0              23
# 2                       0              34
# 3                       0              60
# 4                       0             112
# 5                       0              22
# 6                       0              16
# 7                       0              24
# 8                       0             108
# 9                       0               7
#
#                                    cdc_name                 cdc_street  \
# 0   Bay Area Employment Development Company     1801 Oakland Boulevard
# 1   Bay Area Employment Development Company     1801 Oakland Boulevard
# 2              SBA - EDF Enforcement Action  SBA Denver Finance Center
# 3  Mortgage Capital Development Corporation              1720 Broadway
# 4                Capital Access Group, Inc.      150 California Street
# 5   Bay Area Employment Development Company     1801 Oakland Boulevard
# 6   Bay Area Employment Development Company     1801 Oakland Boulevard
# 7   Bay Area Employment Development Company     1801 Oakland Boulevard
# 8                Capital Access Group, Inc.      150 California Street
# 9   Arcata Economic Development Corporation          100 Ericson Court
#
#         cdc_city cdc_state  cdc_zip third_party_lender_name  \
# 0   Walnut Creek        CA  94596.0                    None
# 1   Walnut Creek        CA  94596.0                    None
# 2         Denver        CO  80202.0                    None
# 3        Oakland        CA  94612.0                    None
# 4  San Francisco        CA  94111.0                    None
# 5   Walnut Creek        CA  94596.0                    None
# 6   Walnut Creek        CA  94596.0                    None
# 7   Walnut Creek        CA  94596.0                    None
# 8  San Francisco        CA  94111.0                    None
# 9         Arcata        CA  95521.0                    None
#
#   third_party_lender_city third_party_lender_state third_party_dollars  \
# 0                    None                     None                None
# 1                    None                     None                None
# 2                    None                     None                None
# 3                    None                     None                None
# 4                    None                     None                None
# 5                    None                     None                None
# 6                    None                     None                None
# 7                    None                     None                None
# 8                    None                     None                None
# 9                    None                     None                None
#
#   bank_name bank_street bank_city bank_state bank_zip sba_guaranteed_approval  \
# 0      None        None      None       None     None                    None
# 1      None        None      None       None     None                    None
# 2      None        None      None       None     None                    None
# 3      None        None      None       None     None                    None
# 4      None        None      None       None     None                    None
# 5      None        None      None       None     None                    None
# 6      None        None      None       None     None                    None
# 7      None        None      None       None     None                    None
# 8      None        None      None       None     None                    None
# 9      None        None      None       None     None                    None
#
#   revolver_status
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
