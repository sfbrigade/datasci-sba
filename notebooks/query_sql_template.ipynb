# %% [markdown]
# # SQL Querying

# %% [markdown]
# This notebook can be used to query tables in the SBA database. In order to use this notebook, you will need to set an environment variable 'SBA_DWH' to the database connection string. If you do not have the credentials, please slack us at #datasci-sba channel.
#
# **It is best practice to not hard code database URI strings directly in notebooks or code as when we push to Github, that would mean credentials are public for anyone to see.**

# %%
import os

import pandas as pd
pd.options.display.max_columns = 999
import sqlalchemy as sqla
from sqlalchemy import create_engine

SBA_DWH = os.getenv('SBA_DWH')
engine = create_engine(SBA_DWH)

# %% [markdown]
# Below are the tables that currently exist in the database!

# %%
QUERY = """
select *
from information_schema.tables
where table_schema not in ('information_schema', 'pg_catalog', 'public')
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(100)
# Out:
#   table_catalog table_schema                  table_name  table_type  \
# 0      postgres  data_ingest   sba__foia_7a_2010_present  BASE TABLE
# 1      postgres  data_ingest      sba__foia_7a_1991_1999  BASE TABLE
# 2      postgres  data_ingest      sba__foia_7a_2000_2009  BASE TABLE
# 3      postgres  data_ingest  sba__foia_504_1991_present  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
# 2                         None                 None                      None
# 3                         None                 None                      None
#
#   user_defined_type_schema user_defined_type_name is_insertable_into is_typed  \
# 0                     None                   None                YES       NO
# 1                     None                   None                YES       NO
# 2                     None                   None                YES       NO
# 3                     None                   None                YES       NO
#
#   commit_action
# 0          None
# 1          None
# 2          None
# 3          None

# %% [markdown]
# ## Edit your own query here!

# %%
QUERY = """
select *
from data_ingest.sba__foia_7a_2010_present
limit 10
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(100)
# Out:
#   Program                       BorrName                     BorrStreet  \
# 0      7A  CRESA PARTNERS - DENVER, INC.  7979 E TUFTS AVE PKWY STE 810
# 1      7A             The Hilltop Tavern               4757 Folsom Blvd
# 2      7A        River City Car Wash LLC                649 Harbor Blvd
# 3      7A                  Alphagraphics               71 Newtown Road.
# 4      7A  ON SITE AUTOMOTIVE APPEARANCE           603 WOODBRIDGE COURT
# 5      7A                 AW ENTERPRISES           106 WEST LAKE STREET
# 6      7A                   TA SPECIALTY          331 HEATHERSTONE ROAD
# 7      7A          Hansen Concrete, Inc.            8656 71st Street NE
# 8      7A           SHADIA'S SECRETS INC        950 GLADES RD 2ND FLOOR
# 9      7A  JT'S COFFEE AND SANDWICH SHOP           1167 HARRISON STREET
#
#           BorrCity BorrState  BorrZip  \
# 0           DENVER        CO    80237
# 1       Sacramento        CA    95819
# 2  West Sacramento        CA    95691
# 3          Danbury        CT     6810
# 4       MIDDLEBURY        IN    46540
# 5           CAMDEN        TN    38320
# 6         COLUMBIA        SC    29212
# 7           SPICER        MN    56288
# 8       BOCA RATON        FL    33431
# 9    SAN FRANCISCO        CA    94103
#
#                                    BankName         BankStreet  \
# 0                 Zions Bank, A Division of        1 S Main St
# 1                               Plumas Bank    35 S Lindan Ave
# 2    Wells Fargo Bank, National Association  101 N Philips Ave
# 3                        Union Savings Bank        226 Main St
# 4  Crossroads Small Business Solutions, LLC  9385 Haven Avenue
# 5  Crossroads Small Business Solutions, LLC  9385 Haven Avenue
# 6  Crossroads Small Business Solutions, LLC  9385 Haven Avenue
# 7                          Lake Region Bank         51 Main St
# 8  Crossroads Small Business Solutions, LLC  9385 Haven Avenue
# 9  Crossroads Small Business Solutions, LLC  9385 Haven Avenue
#
#            BankCity BankState BankZip  GrossApproval  SBAGuaranteedApproval  \
# 0    SALT LAKE CITY        UT   84133         250000                 125000
# 1            QUINCY        CA   95971         233500                 210150
# 2       SIOUX FALLS        SD   57104         683900                 615510
# 3           DANBURY        CT   06810         100000                  50000
# 4  Rancho Cucamonga        CA   91730          12500                  11250
# 5  Rancho Cucamonga        CA   91730          10000                   9000
# 6  Rancho Cucamonga        CA   91730          20000                  18000
# 7        NEW LONDON        MN   56273         200000                 100000
# 8  Rancho Cucamonga        CA   91730          15000                  13500
# 9  Rancho Cucamonga        CA   91730          20000                  18000
#
#   ApprovalDate  ApprovalFiscalYear FirstDisbursementDate DeliveryMethod  \
# 0   2009-10-01                2010            2009-10-01     SBA EXPRES
# 1   2009-10-01                2010            2009-10-01            PLP
# 2   2009-10-01                2010            2009-11-01            PLP
# 3   2009-10-01                2010            2009-10-01     SBA EXPRES
# 4   2009-10-01                2010            2009-10-01     COMM EXPRS
# 5   2009-10-01                2010            2009-10-01     COMM EXPRS
# 6   2009-10-01                2010            2009-10-01     PATRIOT EX
# 7   2009-10-01                2010            2009-12-01     SBA EXPRES
# 8   2009-10-01                2010            2009-10-01     COMM EXPRS
# 9   2009-10-01                2010            2009-10-01     COMM EXPRS
#
#                     subpgmdesc  InitialInterestRate  TermInMonths  NaicsCode  \
# 0  FA$TRK (Small Loan Express)                 5.26            84   531210.0
# 1                     Guaranty                 6.00           120   722410.0
# 2                     Guaranty                 5.25           210   811192.0
# 3  FA$TRK (Small Loan Express)                 5.25            84   323110.0
# 4            Community Express                 7.75           120   811121.0
# 5            Community Express                 7.24           120   453220.0
# 6              Patriot Express                 7.75           120   541890.0
# 7  FA$TRK (Small Loan Express)                 7.50            60   236220.0
# 8            Community Express                 7.75           120   446199.0
# 9            Community Express                 7.75           120   722213.0
#
#                                     NaicsDescription  FranchiseCode  \
# 0          Offices of Real Estate Agents and Brokers              0
# 1              Drinking Places (Alcoholic Beverages)              0
# 2                                         Car Washes              0
# 3                   Commercial Lithographic Printing           3512
# 4  Automotive Body, Paint, and Interior Repair an...              0
# 5                 Gift, Novelty, and Souvenir Stores              0
# 6              Other Services Related to Advertising              0
# 7  Commercial and Institutional Building Construc...              0
# 8          All Other Health and Personal Care Stores              0
# 9               Snack and Nonalcoholic Beverage Bars              0
#
#                     FranchiseName  ProjectCounty ProjectState  \
# 0                            None         DENVER           CO
# 1                            None     SACRAMENTO           CA
# 2                            None           YOLO           CA
# 3  ALPHAGRAPHICS, PRINTSHOPS OF T      FAIRFIELD           CT
# 4                            None        ELKHART           IN
# 5                            None         BENTON           TN
# 6                            None      LEXINGTON           SC
# 7                            None      KANDIYOHI           MN
# 8                            None     PALM BEACH           FL
# 9                            None  SAN FRANCISCO           CA
#
#                  SBADistrictOffice  CongressionalDistrict BusinessType  \
# 0        COLORADO DISTRICT OFFICE                     1.0  CORPORATION
# 1      SACRAMENTO DISTRICT OFFICE                     6.0  CORPORATION
# 2      SACRAMENTO DISTRICT OFFICE                     6.0  CORPORATION
# 3     CONNECTICUT DISTRICT OFFICE                     5.0  CORPORATION
# 4         INDIANA DISTRICT OFFICE                     2.0   INDIVIDUAL
# 5       TENNESSEE DISTRICT OFFICE                     7.0   INDIVIDUAL
# 6  SOUTH CAROLINA DISTRICT OFFICE                     2.0   INDIVIDUAL
# 7       MINNESOTA DISTRICT OFFICE                     7.0  CORPORATION
# 8   SOUTH FLORIDA DISTRICT OFFICE                    22.0  CORPORATION
# 9   SAN FRANCISCO DISTRICT OFFICE                    12.0  CORPORATION
#
#   LoanStatus ChargeOffDate  GrossChargeOffAmount  RevolverStatus  \
# 0        PIF           NaT                     0               1
# 1     EXEMPT           NaT                     0               0
# 2     CHGOFF    2015-08-24                320098               0
# 3     EXEMPT           NaT                     0               1
# 4        PIF           NaT                     0               0
# 5     EXEMPT           NaT                     0               0
# 6     EXEMPT           NaT                     0               0
# 7        PIF           NaT                     0               1
# 8     EXEMPT           NaT                     0               0
# 9     EXEMPT           NaT                     0               0
#
#    JobsSupported
# 0             35
# 1              6
# 2             27
# 3              5
# 4              2
# 5              3
# 6              4
# 7             12
# 8              1
# 9              4
