# %% [markdown]
# # SQL Querying

# %% [markdown]
# This notebook can be used to query tables in the SBA database. In order to use this notebook, you will need to set an environment variable 'SBA_DWH' to the database connection string. If you do not have the credentials, please slack us at #datasci-sba channel.
#
# **It is best practice to not hard code database URI strings directly in notebooks or code as when we push to Github, that would mean credentials are public for anyone to see.**

# %%
import os

import pandas as pd
pd.options.display.max_columns = 999
import sqlalchemy as sqla
from sqlalchemy import create_engine

SBA_DWH = os.getenv('SBA_DWH')
engine = create_engine(SBA_DWH)

# %% [markdown]
# Below are the tables that currently exist in the database:

# %%
QUERY = """
select *
from information_schema.tables
where table_schema not in ('information_schema', 'pg_catalog', 'public')
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(100)
# Out:
#   table_catalog   table_schema                     table_name  table_type  \
# 0      postgres    data_ingest      sba__foia_7a_2010_present  BASE TABLE
# 1      postgres    data_ingest  census__zip_business_patterns  BASE TABLE
# 2      postgres    data_ingest         sba__foia_7a_1991_1999  BASE TABLE
# 3      postgres    data_ingest         sba__foia_7a_2000_2009  BASE TABLE
# 4      postgres  stg_analytics                       sba_sfdo  BASE TABLE
# 5      postgres    data_ingest     sba__foia_504_1991_present  BASE TABLE
# 6      postgres    data_ingest                  irs__zip_data  BASE TABLE
# 7      postgres  stg_analytics                     irs_income  BASE TABLE
# 8      postgres  stg_analytics                   census_naics  BASE TABLE
# 9      postgres  trg_analytics                  sba_zip_level  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
# 2                         None                 None                      None
# 3                         None                 None                      None
# 4                         None                 None                      None
# 5                         None                 None                      None
# 6                         None                 None                      None
# 7                         None                 None                      None
# 8                         None                 None                      None
# 9                         None                 None                      None
#
#   user_defined_type_schema user_defined_type_name is_insertable_into is_typed  \
# 0                     None                   None                YES       NO
# 1                     None                   None                YES       NO
# 2                     None                   None                YES       NO
# 3                     None                   None                YES       NO
# 4                     None                   None                YES       NO
# 5                     None                   None                YES       NO
# 6                     None                   None                YES       NO
# 7                     None                   None                YES       NO
# 8                     None                   None                YES       NO
# 9                     None                   None                YES       NO
#
#   commit_action
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# 5          None
# 6          None
# 7          None
# 8          None
# 9          None

# %% [markdown]
# ### List all the CDC and Bank names in the data

# %%
QUERY = """
SELECT cdc_name, cdc_city, cdc_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE cdc_name IS NOT NULL
    GROUP BY cdc_name, cdc_city, cdc_state ORDER BY count
LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(100)
# Out:
#                                              cdc_name         cdc_city  \
# 0                                MISSNG/INACTV LENDER             None
# 1                            Coastal Business Finance      Santa Maria
# 2          Northwest Business Development Association   Spokane Valley
# 3                      Cen Cal Business Finance Group           Fresno
# 4   Success Capital Expansion & Development Corpor...          Modesto
# 5                           AMPAC Tri-State CDC, Inc.    Grand Terrace
# 6                           SBA Denver Finance Center           Denver
# 7                            Business Finance Capital      Los Angeles
# 8                                MISSNG/INACTV LENDER       WASHINGTON
# 9                                MISSNG/INACTV LENDER          Salinas
# 10     Pacific West Certified Development Corporation     Laguna Hills
# 11        Advantage Certified Development Corporation       Long Beach
# 12                               MISSNG/INACTV LENDER       Washington
# 13        Southland Economic  Development Corporation        Santa Ana
# 14     Superior California Economic Development, Inc.          Redding
# 15      Los Medanos Fund, A Local Development Company       Pittsburgh
# 16  Greater Sacramento Certified Development Corpo...  North Highlands
# 17            Arcata Economic Development Corporation           Arcata
# 18  California Statewide Certified Development Cor...            Davis
# 19             CDC Small Business Finance Corporation        San Diego
# 20                       SBA - EDF Enforcement Action           Denver
# 21                         Capital Access Group, Inc.    San Francisco
# 22            Bay Area Employment Development Company     Walnut Creek
# 23           Mortgage Capital Development Corporation          Oakland
#
#    cdc_state  count
# 0       None      1
# 1         CA      1
# 2         WA      2
# 3         CA      4
# 4         CA      5
# 5         CA      6
# 6         CO      9
# 7         CA      9
# 8         DC     10
# 9         CA     10
# 10        CA     10
# 11        CA     15
# 12        DC     16
# 13        CA     18
# 14        CA     21
# 15        CA     35
# 16        CA     50
# 17        CA     88
# 18        CA     92
# 19        CA    200
# 20        CO    232
# 21        CA   1386
# 22        CA   1953
# 23        CA   2892

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name IS NOT NULL 
    GROUP BY bank_name, bank_city, bank_state ORDER BY count DESC
    LIMIT 250
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(100)
# Out:
#                                            bank_name          bank_city  \
# 0             Wells Fargo Bank, National Association        SIOUX FALLS
# 1              Bank of America, National Association          CHARLOTTE
# 2                     U.S. Bank National Association         Cincinnati
# 3                                       Bank of Hope        LOS ANGELES
# 4                                        Umpqua Bank           ROSEBURG
# 5          JPMorgan Chase Bank, National Association           COLUMBUS
# 6                                      Comerica Bank             DALLAS
# 7                          Heritage Bank of Commerce           SAN JOSE
# 8                                     Citibank, N.A.        SIOUX FALLS
# 9                          Zions Bank, A Division of     SALT LAKE CITY
# 10                                  Bank of the West      SAN FRANCISCO
# 11                 Capital One, National Association             MCLEAN
# 12  Bank of America California, National Association      SAN FRANCISCO
# 13                     Loans from Old Closed Lenders         Washington
# 14             Federal Deposit Insurance Corporation         WASHINGTON
# 15                                  Westamerica Bank         SAN RAFAEL
# 16             MUFG Union Bank, National Association      SAN FRANCISCO
# 17                             Readycap Lending, LLC     NEW PROVIDENCE
# 18                                    East West Bank           PASADENA
# 19                                        First Bank        CREVE COEUR
# 20                                City National Bank        LOS ANGELES
# 21     GE Capital Small Business Finance Corporation            HOUSTON
# 22          Crossroads Small Business Solutions, LLC   Rancho Cucamonga
# 23                             Western Alliance Bank            PHOENIX
# 24                            Santa Cruz County Bank         SANTA CRUZ
# 25                        Wachovia SBA Lending, Inc.          ROSEVILLE
# 26                                Main Street Launch            Oakland
# 27                                        Redwood CU         SANTA ROSA
# 28                           Santa Cruz Community CU         SANTA CRUZ
# 29                                BAC Community Bank           STOCKTON
# ..                                               ...                ...
# 70                                   First Home Bank           SEMINOLE
# 71                                 Metropolitan Bank            OAKLAND
# 72         Golden Pacific Bank, National Association         SACRAMENTO
# 73                                        Plaza Bank             IRVINE
# 74                                     Vision One CU         SACRAMENTO
# 75                                       KeyPoint CU        SANTA CLARA
# 76        Community Banks of Colorado, A Division of  GREENWOOD VILLAGE
# 77                                     Technology CU           SAN JOSE
# 78                 Stearns Bank National Association        SAINT CLOUD
# 79                            Washington Mutual Bank          HENDERSON
# 80                                  EH National Bank      BEVERLY HILLS
# 81                         Spirit of Texas Bank, SSB    COLLEGE STATION
# 82                              United Security Bank             FRESNO
# 83                                     Bank of Marin             NOVATO
# 84                                       Summit Bank            OAKLAND
# 85            CDC Small Business Finance Corporation          San Diego
# 86                                   Lighthouse Bank         SANTA CRUZ
# 87                               American River Bank         SACRAMENTO
# 88                      Aurora Interim National Bank          LITTLETON
# 89                       UPS Capital Business Credit            WINDSOR
# 90                                       Banner Bank        WALLA WALLA
# 91                 Valley Economic Development Corp.           Van Nuys
# 92                             San Francisco Fire CU      SAN FRANCISCO
# 93          Banc of California, National Association             IRVINE
# 94                  Savings Bank of Mendocino County              UKIAH
# 95                             Business Lenders, LLC           HARTFORD
# 96                       California Bank of Commerce          LAFAYETTE
# 97      Capital One Bank (USA), National Association         GLEN ALLEN
# 98              CRF Small Business Loan Company, LLC        MINNEAPOLIS
# 99                        World Trade Finance,  Inc.            BURBANK
#
#    bank_state  count
# 0          SD   8419
# 1          NC   3276
# 2          OH   2208
# 3          CA   1903
# 4          OR   1360
# 5          OH   1265
# 6          TX   1031
# 7          CA   1001
# 8          SD    992
# 9          UT    901
# 10         CA    895
# 11         VA    842
# 12         CA    767
# 13         DC    698
# 14         DC    627
# 15         CA    626
# 16         CA    554
# 17         NJ    470
# 18         CA    449
# 19         MO    421
# 20         CA    408
# 21         TX    393
# 22         CA    348
# 23         AZ    277
# 24         CA    262
# 25         CA    221
# 26         CA    220
# 27         CA    209
# 28         CA    206
# 29         CA    197
# ..        ...    ...
# 70         FL     43
# 71         CA     42
# 72         CA     42
# 73         CA     41
# 74         CA     38
# 75         CA     36
# 76         CO     36
# 77         CA     36
# 78         MN     36
# 79         NV     35
# 80         CA     34
# 81         TX     31
# 82         CA     30
# 83         CA     30
# 84         CA     30
# 85         CA     29
# 86         CA     29
# 87         CA     29
# 88         CO     29
# 89         CT     26
# 90         WA     26
# 91         CA     26
# 92         CA     25
# 93         CA     23
# 94         CA     23
# 95         CT     23
# 96         CA     23
# 97         VA     22
# 98         MN     22
# 99         CA     22
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Run various keyword queries that hit all the names in CACFDIs.xlsx

# %% [markdown]
# This query results in a possible match for `Valley Economic Development Center, Van Nuys`

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%valley%%' 
    GROUP BY bank_name, bank_city, bank_state ORDER by bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                            bank_name    bank_city bank_state  count
# 0      Central Valley Community Bank       FRESNO         CA      9
# 1                Mission Valley Bank   SUN VALLEY         CA      2
# 2          Oak Valley Community Bank      OAKDALE         CA      4
# 3                Pacific Valley Bank      SALINAS         CA      1
# 4                Premier Valley Bank       FRESNO         CA      8
# 5                  Scott Valley Bank        YREKA         CA      2
# 6                Silicon Valley Bank  SANTA CLARA         CA     16
# 7                    Tri-Valley Bank    SAN RAMON         CA     17
# 8              Valley Community Bank   PLEASANTON         CA      3
# 9  Valley Economic Development Corp.     Van Nuys         CA     26

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%core%%'
    GROUP by bank_name, bank_city, bank_state ORDER by count DESC
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
# Empty DataFrame
# Columns: [bank_name, bank_city, bank_state, count]
# Index: []

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%accion%%'
    GROUP by bank_name, bank_city, bank_state ORDER by count DESC
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
# Empty DataFrame
# Columns: [bank_name, bank_city, bank_state, count]
# Index: []

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%america%%'
    GROUP BY bank_name, bank_city, bank_state ORDER by bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                                            bank_name         bank_city  \
# 0                          American Continental Bank  CITY OF INDUSTRY
# 1                    American Express Centurion Bank    SALT LAKE CITY
# 2                             American National Bank             OMAHA
# 3                                American River Bank        SACRAMENTO
# 4                              American Riviera Bank     SANTA BARBARA
# 5                                  AmericanWest Bank           ONTARIO
# 6                               Americas United Bank          GLENDALE
# 7                        Banco Popular North America     NEW YORK CITY
# 8   Bank of America California, National Association     SAN FRANCISCO
# 9              Bank of America, National Association         CHARLOTTE
# 10                   Grow America Fund, Incorporated          NEW YORK
# 11                              Shinhan Bank America     NEW YORK CITY
# 12         Transamerica Small Business Capital, Inc.        GREENVILLE
# 13                              United American Bank         SAN MATEO
# 14                                  Westamerica Bank        SAN RAFAEL
#
#    bank_state  count
# 0          CA      5
# 1          UT     11
# 2          NE      4
# 3          CA     29
# 4          CA      2
# 5          CA      1
# 6          CA      1
# 7          NY     85
# 8          CA    767
# 9          NC   3276
# 10         NY     21
# 11         NY      9
# 12         SC      4
# 13         CA     49
# 14         CA    626

# %% [markdown]
# This query finds two possible matches. `TMC Development Working Solutions, San Francisco` and `Valley Economic Development Center, Van Nuys`.
# The latter matches other keyword searches. Google cross-referencing on TMC and The Mortgage Capital Devlopment is not conclusive.

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%development%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                                            bank_name      bank_city  \
# 0  Community Development Transportation Lending S...  Washington DC
# 1     Empire State Certified Development Corporation         Albany
# 2       The Mortgage Capital Development Corporation  San Francisco
# 3                  Valley Economic Development Corp.       Van Nuys
#
#   bank_state  count
# 0         DC      2
# 1         NY      1
# 2         CA      9
# 3         CA     26

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%village%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
# Empty DataFrame
# Columns: [bank_name, bank_city, bank_state, count]
# Index: []

# %% [markdown]
# This yields a possible match for `Bankers' Small Business CDC of San Diego`. Google hits for the two names are very similar.

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%business%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                                         bank_name         bank_city  \
# 0                           Business Lenders, LLC          HARTFORD
# 1                       Business Loan Center, LLC        GREENVILLE
# 2          CDC Small Business Finance Corporation         San Diego
# 3          CIT Small Business Lending Corporation        LIVINGSTON
# 4        CitiCapital Small Business Finance, Inc.            IRVING
# 5                          Citizens Business Bank           ONTARIO
# 6                      Commonwealth Business Bank       LOS ANGELES
# 7            CRF Small Business Loan Company, LLC       MINNEAPOLIS
# 8        Crossroads Small Business Solutions, LLC  Rancho Cucamonga
# 9      Freedom Small Business Lending BIDCO, Inc.            NEWARK
# 10  GE Capital Small Business Finance Corporation           HOUSTON
# 11              Hana Small Business Lending, Inc.       LOS ANGELES
# 12            Harvest Small Business Finance, LLC      Laguna Hills
# 13            Newtek Small Business Finance, Inc.      LAKE SUCCESS
# 14                          Premier Business Bank       LOS ANGELES
# 15                            Royal Business Bank       LOS ANGELES
# 16                            Small Business Bank           GARDNER
# 17                Small Business Loan Source, LLC           HOUSTON
# 18                  Textron Business Credit, Inc.        PROVIDENCE
# 19      Transamerica Small Business Capital, Inc.        GREENVILLE
# 20                   United Business Bank, F.S.B.           OAKLAND
# 21                    UPS Capital Business Credit           WINDSOR
#
#    bank_state  count
# 0          CT     23
# 1          SC     59
# 2          CA     29
# 3          NJ      1
# 4          TX    131
# 5          CA      1
# 6          CA      4
# 7          MN     22
# 8          CA    348
# 9          DE      1
# 10         TX    393
# 11         CA     56
# 12         CA     21
# 13         NY     60
# 14         CA      1
# 15         CA      4
# 16         KS      4
# 17         TX      3
# 18         RI      7
# 19         SC      4
# 20         CA      6
# 21         CT     26

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%union%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                                bank_name      bank_city bank_state  count
# 0  MUFG Union Bank, National Association  SAN FRANCISCO         CA    554
# 1   National Credit Union Administration     ALEXANDRIA         VA      6

# %% [markdown]
# This yields an exact match for `Beneficial State Bank, Oakland`.

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%beneficial%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                bank_name     bank_city bank_state  count
# 0        Beneficial Bank  PHILADELPHIA         PA      3
# 1  Beneficial State Bank       OAKLAND         CA     45

# %% [markdown]
# This yields an exact match for `Community Bank of the Bay, Oakland` and a very close match for `Santa Cruz Community Credit Union, Santa Cruz`

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%community%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                                             bank_name          bank_city  \
# 0                                  BAC Community Bank           STOCKTON
# 1                       Central Valley Community Bank             FRESNO
# 2                                  Community 1st Bank             AUBURN
# 3                                      Community Bank           PASADENA
# 4                           Community Bank of the Bay            OAKLAND
# 5          Community Banks of Colorado, A Division of  GREENWOOD VILLAGE
# 6   Community Development Transportation Lending S...      Washington DC
# 7           Community West Bank, National Association             GOLETA
# 8                                First Community Bank         SANTA ROSA
# 9                             First U.S. Community CU         SACRAMENTO
# 10                          Oak Valley Community Bank            OAKDALE
# 11                            Santa Cruz Community CU         SANTA CRUZ
# 12                              United Community Bank        BLAIRSVILLE
# 13                              Valley Community Bank         PLEASANTON
#
#    bank_state  count
# 0          CA    197
# 1          CA      9
# 2          CA      4
# 3          CA      8
# 4          CA    102
# 5          CO     36
# 6          DC      2
# 7          CA    120
# 8          CA    184
# 9          CA      2
# 10         CA      4
# 11         CA    206
# 12         GA      2
# 13         CA      3

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%farm%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                                         bank_name   bank_city bank_state  \
# 0                Farmers & Merchants Bank & Trust  BURLINGTON         IA
# 1  Farmers & Merchants Bank of Central California        LODI         CA
#
#    count
# 0      1
# 1      4

# %% [markdown]
# This one matches picks up `Valley Economic Development Center, Van Nuys`, which a Google search seems to indicate is a match for `Valley Economic Development Corp.`

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%economic%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                            bank_name bank_city bank_state  count
# 0  Valley Economic Development Corp.  Van Nuys         CA     26

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%home%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                            bank_name bank_city bank_state  count
# 0                    First Home Bank  SEMINOLE         FL     43
# 1  Home Loan Investment Bank, F.S.B.   WARWICK         RI      1
# 2                    HomeStreet Bank   SEATTLE         WA      1

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%housing%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
# Empty DataFrame
# Columns: [bank_name, bank_city, bank_state, count]
# Index: []

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%financ%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name 
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                                         bank_name     bank_city bank_state  \
# 0          CDC Small Business Finance Corporation     San Diego         CA
# 1                          Choice Financial Group         FARGO         ND
# 2        CitiCapital Small Business Finance, Inc.        IRVING         TX
# 3                     First Bank Financial Centre    OCONOMOWOC         WI
# 4                            First Financial Bank    CINCINNATI         OH
# 5                            First Financial Bank     EL DORADO         AR
# 6      First Financial Bank, National Association      HAMILTON         OH
# 7   GE Capital Small Business Finance Corporation       HOUSTON         TX
# 8             Harvest Small Business Finance, LLC  Laguna Hills         CA
# 9             Newtek Small Business Finance, Inc.  LAKE SUCCESS         NY
# 10                         Textron Financial Corp    PROVIDENCE         RI
# 11                     World Trade Finance,  Inc.       BURBANK         CA
# 12                     World Trade Finance,  Inc.  Santa Monica         CA
# 13                            Xceed Financial FCU    EL SEGUNDO         CA
#
#     count
# 0      29
# 1       2
# 2     131
# 3       3
# 4       1
# 5       2
# 6       1
# 7     393
# 8      21
# 9      60
# 10      1
# 11     22
# 12      4
# 13      5

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%choice%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                 bank_name bank_city bank_state  count
# 0  Choice Financial Group     FARGO         ND      2

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%income%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
# Empty DataFrame
# Columns: [bank_name, bank_city, bank_state, count]
# Index: []

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%neighborhood%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
# Empty DataFrame
# Columns: [bank_name, bank_city, bank_state, count]
# Index: []

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%one%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                                       bank_name    bank_city bank_state  count
# 0  Capital One Bank (USA), National Association   GLEN ALLEN         VA     22
# 1             Capital One, National Association       MCLEAN         VA    842
# 2                 CenterStone SBA Lending, Inc.  LOS ANGELES         CA      1
# 3         Credit One Bank, National Association    LAS VEGAS         NV      4
# 4                                MutualOne Bank   FRAMINGHAM         MA      1
# 5                                 Vision One CU   SACRAMENTO         CA     38

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%opening%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
# Empty DataFrame
# Columns: [bank_name, bank_city, bank_state, count]
# Index: []

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%opportunity%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
# Empty DataFrame
# Columns: [bank_name, bank_city, bank_state, count]
# Index: []

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%trail%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
# Empty DataFrame
# Columns: [bank_name, bank_city, bank_state, count]
# Index: []

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%poverty%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
# Empty DataFrame
# Columns: [bank_name, bank_city, bank_state, count]
# Index: []

# %% [markdown]
# The following yields an exact match for `SCE FCU, Irwindale`.

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%sce%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#   bank_name  bank_city bank_state  count
# 0   SCE FCU  IRWINDALE         CA      1

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%alliance%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                bank_name bank_city bank_state  count
# 0  Western Alliance Bank   PHOENIX         AZ    277

# %%
QUERY = """
SELECT bank_name, bank_city, bank_state, count(*)
    FROM stg_analytics.sba_sfdo WHERE bank_name ILIKE '%%federal%%'
    GROUP BY bank_name, bank_city, bank_state ORDER BY bank_name
    LIMIT 25
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(25)
# Out:
#                                bank_name   bank_city bank_state  count
# 0  Federal Deposit Insurance Corporation  WASHINGTON         DC    627
