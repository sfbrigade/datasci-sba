# %% [markdown]
# # Geocoding Loan Dataset

# %%
import os
import sys
sys.path.append('../')

import pandas as pd
import sqlalchemy as sqla
from sqlalchemy import create_engine

SBA_DWH = os.getenv('SBA_DWH')
engine = create_engine(SBA_DWH)

from googleplaces import GooglePlaces, types, lang
from utilities import geocoder


YOUR_API_KEY = os.getenv('GOOGLE_PLACES_API')

# %%
# This will be abstracted/replaced later (possibly reading from URI)
with engine.begin() as conn:
    df = pd.read_sql_table('sba_sfdo', conn, 'stg_analytics')
df['address'] = df.borr_street + ',' + df.borr_city + ',' + df.borr_state + ',' + df.borr_zip.map(str)

# %%
df = geocoder.geocode(df=df, api_key=YOUR_API_KEY)
# Out:
# 549 GARCIA AVENUE, LOTS 6,7,PITTSBURG,CA,94565
# 0
# ---------------------------------------------------------------------------
# GooglePlacesError                         Traceback (most recent call last)
# /Users/VincentLa/anaconda3/lib/python3.6/site-packages/googleplaces/__init__.py in _generate_lat_lng_string(self, lat_lng, location)
#     587             return '%(lat)s,%(lng)s' % (lat_lng if lat_lng is not None
# --> 588                     else geocode_location(location))
#     589         except:
#
# /Users/VincentLa/anaconda3/lib/python3.6/site-packages/googleplaces/__init__.py in geocode_location(location, sensor)
#     120                         location)
# --> 121         raise GooglePlacesError(error_detail)
#     122     return geo_response['results'][0]['geometry']['location']
#
# GooglePlacesError: Lat/Lng for location '549 GARCIA AVENUE, LOTS 6,7,PITTSBURG,CA,94565' can't be determined.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-0f917dafa8d7> in <module>()
# ----> 1 df = geocoder.geocode(df=df, api_key=YOUR_API_KEY)
#
# /Users/VincentLa/git/datasci-sba/utilities/geocoder.py in geocode(df, api_key)
#      31         query_result = google_places.nearby_search(
#      32             location=place,
# ---> 33             radius=100
#      34         )
#      35         print(query_result.places)
#
# /Users/VincentLa/anaconda3/lib/python3.6/site-packages/googleplaces/__init__.py in nearby_search(self, language, keyword, location, lat_lng, name, radius, rankby, sensor, type, types, pagetoken)
#     277         radius = (radius if radius <= GooglePlaces.MAXIMUM_SEARCH_RADIUS
#     278                   else GooglePlaces.MAXIMUM_SEARCH_RADIUS)
# --> 279         lat_lng_str = self._generate_lat_lng_string(lat_lng, location)
#     280         self._request_params = {'location': lat_lng_str}
#     281         if rankby == 'prominence':
#
# /Users/VincentLa/anaconda3/lib/python3.6/site-packages/googleplaces/__init__.py in _generate_lat_lng_string(self, lat_lng, location)
#     589         except:
#     590             raise ValueError(
# --> 591                 'lat_lng must be a dict with the keys, \'lat\' and \'lng\'')
#     592
#     593     @property
#
# ValueError: lat_lng must be a dict with the keys, 'lat' and 'lng'

# %%
df.head()
# Out:
#     Column Program                        BorrName              BorrStreet  \
# 0   3098.0      7A            PER CASO PRODUCTIONS       6600 YOUNT ST #12
# 1   4752.0     504                 WINE GARDEN LLC  6476 WASHINGTON STREET
# 2   5338.0      7A                  BORDEAUX HOUSE  6600 WASHINGTON STREET
# 3   5836.0      7A              VITA PARTNERS, LLC  6725 WASHINGTON STREET
# 4  12154.0      7A  NAPA VALLEY BIKE TOURS AND NAP      6488 WASHINGTON ST
#
#      BorrCity BorrState BorrZip                                 BankName  \
# 0  YOUNTVILLE        CA   94599                             Bank of Hope
# 1  YOUNTVILLE        CA   94599  Bay Area Employment Development Company
# 2  YOUNTVILLE        CA   94599                         Bank of the West
# 3  YOUNTVILLE        CA   94599                      First Republic Bank
# 4  YOUNTVILLE        CA   94599   Wells Fargo Bank, National Association
#
#                      BankStreet       BankCity  \
# 0  3731 Wilshire Blvd, Ste 1000    LOS ANGELES
# 1        1801 Oakland Boulevard   Walnut Creek
# 2             180 Montgomery St  SAN FRANCISCO
# 3                   111 Pine St  SAN FRANCISCO
# 4             101 N Philips Ave    SIOUX FALLS
#
#                          ...                         ChargeOffDate  \
# 0                        ...                             6/17/2009
# 1                        ...                                   NaN
# 2                        ...                                   NaN
# 3                        ...                                   NaN
# 4                        ...                                   NaN
#
#    GrossChargeOffAmount  RevolverStatus  JobsSupported ThirdPartyLender_Name  \
# 0               11775.0             0.0            2.0                   NaN
# 1                   0.0             NaN           25.0                   NaN
# 2                   0.0             0.0            0.0                   NaN
# 3                   0.0             0.0           85.0                   NaN
# 4                   0.0             0.0            8.0                   NaN
#
#    ThirdPartyLender_City ThirdPartyLender_State ThirdPartyDollars  \
# 0                    NaN                    NaN               NaN
# 1                    NaN                    NaN               NaN
# 2                    NaN                    NaN               NaN
# 3                    NaN                    NaN               NaN
# 4                    NaN                    NaN               NaN
#
#                                       address  \
# 0       6600 YOUNT ST #12,YOUNTVILLE,CA,94599
# 1  6476 WASHINGTON STREET,YOUNTVILLE,CA,94599
# 2  6600 WASHINGTON STREET,YOUNTVILLE,CA,94599
# 3  6725 WASHINGTON STREET,YOUNTVILLE,CA,94599
# 4      6488 WASHINGTON ST,YOUNTVILLE,CA,94599
#
#                                              matches
# 0  [<Place name="Yountville", lat=38.401578099999...
# 1  [<Place name="Yountville", lat=38.401578099999...
# 2  [<Place name="Yountville", lat=38.401578099999...
# 3  [<Place name="Yountville", lat=38.401578099999...
# 4  [<Place name="Yountville", lat=38.401578099999...
#
# [5 rows x 41 columns]
